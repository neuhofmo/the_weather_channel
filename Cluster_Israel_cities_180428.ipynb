# %% [markdown]
# # Clustering Israel Cities according to coordinates

# %%
# loading only the packages we need
import numpy as np
from os.path import join
from sklearn.cluster import KMeans
import pandas as pd

# %%
folder = r'C:\Users\User\Documents\DMBI_hackathon_2018'
cities_csv = join(folder, r'israel_coordinates.csv')

# %%
# load city file
coor_df = pd.read_csv(cities_csv, index_col='City')
coor_df.dropna(inplace=True)  # remove NAs
cities = coor_df.index  # save list of cities for labeling

# %% [markdown]
# The data looks like this:

# %%
coor_df.head()
# Out:
#                         Latitude  Longitude
# City
# Yerushalayim               31.78      35.22
# Tel aviv-yafo              32.07      34.77
# Haifa                      32.82      34.99
# Rishon lez?iyyon           31.96      34.80
# Ashdod                     31.80      34.64
# Be'er sheva                31.25      34.80
# Petah? tiqwa               32.09      34.88
# Netanya                    32.33      34.86
# H?olon                     32.02      34.76
# Bene beraq                 32.09      34.85
# Bat yam                    32.02      34.75
# Ramat gan                  32.08      34.80
# Ashqelon                   31.67      34.56
# Reh?ovot                   31.89      34.80
# Herzeliyya                 32.17      34.84
# Kefar sava                 32.19      34.91
# H?adera                    32.45      34.92
# Ra'anana                   32.19      34.88
# Lod                        31.96      34.90
# Ramla                      31.93      34.86
# Naz?erat                   32.71      35.30
# Bet shemesh                31.75      34.98
# Modi'in-makkabim-re'ut     31.90      35.01
# Nahariyya                  33.03      35.10
# Qiryat atta                32.81      35.12
# Qiryat gat                 31.61      34.76
# Giv'atayim                 32.06      34.80
# 'akko                      32.94      35.08
# Elat                       29.56      34.95
# Naz?erat 'illit            32.72      35.33
# ...                          ...        ...
# Ramat ef'al                32.05      34.83
# Yavne'el                   32.71      35.50
# Mi'elya                    33.03      35.26
# Jish                       33.02      35.44
# Elyakhin                   32.40      34.92
# Newe deqalim               31.35      34.27
# Bet arye                   32.03      35.05
# 'immanu'el                 32.15      35.13
# Uzeir                      32.79      35.33
# Rosh pinna                 32.97      35.53
# Sulam                      32.61      35.33
# Sheikh dannun              32.99      35.15
# 'ofra                      31.92      35.23
# Kefar tavor                32.69      35.42
# Nordiyya                   32.32      34.90
# Eli                        32.07      35.27
# Nehalim                    32.06      34.91
# Ibtin                      32.76      35.10
# Kefar adummim              31.82      35.33
# 'ein qiniyye               31.93      35.15
# Shilo                      32.05      35.28
# Har adar                   31.82      35.13
# Timrat                     32.70      35.23
# Sallama                    32.90      35.37
# Kefar shemaryahu           32.19      34.82
# Talmon                     31.93      35.12
# Bet yizhaq                 32.32      34.88
# Nein                       32.63      35.35
# Na'ura                     32.61      35.39
# Rumat heib                 32.78      35.31
#
# [193 rows x 2 columns]

# %%
# and the list of cities:
cities
# Out:
# Index(['Yerushalayim', 'Tel aviv-yafo', 'Haifa', 'Rishon lez?iyyon', 'Ashdod',
#        'Be'er sheva', 'Petah? tiqwa', 'Netanya', 'H?olon', 'Bene beraq',
#        ...
#        'Shilo', 'Har adar', 'Timrat', 'Sallama', 'Kefar shemaryahu', 'Talmon',
#        'Bet yizhaq', 'Nein', 'Na'ura', 'Rumat heib'],
#       dtype='object', name='City', length=193)

# %%
# fitting function
def kmeans_print_groups(n_clusters, X=coor_df, cities=cities):
    """Receives a number of clusters (int) and prints the scrolls in each cluster after performing
    K-means on the X matrix."""
    kmeans = KMeans(n_clusters=n_clusters, n_init=100, max_iter=3000).fit(X)
    for i in range(max(kmeans.labels_) + 1):  # label
        print(f"Group {i+1}: {sorted(cities[(kmeans.labels_ == i)])}")

# %% [markdown]
# ### Fitting based on number of clusters (K)

# %%
kmeans_print_groups(n_clusters=10)
# Out:
# Group 1: ["'akko", "'atlit", "'ir hahamisha", "Basmat tab'un", "Daliyat al karmel-'isifya", 'Haifa', "I'billin", 'Ibtin', 'Judeide-maker', 'Kabul', 'Kafar manda', 'Kafar yasif', "Mazra'a", 'Nahariyya', 'Nesher', 'Qiryat atta', 'Qiryat bialik', 'Qiryat motzkin', "Qiryat tiv'on", 'Qiryat yam', 'Ramat yishay', 'Rekhasim', 'Segev-shalom', "Sha'ab", "Shefar'am", 'Sheikh dannun', 'Shelomi', 'Tamra', 'Tirat karmel', "Yoqne'am illit"]
# Group 2: ["'immanu'el", 'Alfe menashe', 'Azur', 'Bat yam', "Be'er ya'aqov", 'Bene beraq', 'Bet arye', 'Bet dagan', 'Elqana', 'Ganne tiqwa', 'Gedera', "Giv'at shemuel", "Giv'atayim", 'H?olon', 'Herzeliyya', 'Hod hasharon', 'Jaljulye', 'Kafar qasem', 'Kefar habad', 'Kefar sava', 'Kefar shemaryahu', 'Lod', 'Mazkeret batya', 'Nehalim', 'Nes z?iyyona', 'Or yehuda', 'Oranit', 'Petah? tiqwa', 'Qarne shomeron', "Qiryat 'eqron", 'Qiryat ono', "Ra'anana", "Ramat ef'al", 'Ramat gan', 'Ramat hasharon', 'Ramla', 'Reh?ovot', 'Rishon lez?iyyon', 'Rosh haayin', 'Savyon', "Sha'are tiqwa", 'Shoham', 'Tel aviv-yafo', 'Yavne', 'Yehud-newe efrayim']
# Group 3: ["Binyamina-giv'at ada"]
# Group 4: ["'arad", "'omer", "Be'er sheva", 'Dimona', 'Kuseife', 'Merkaz shappira', 'Mizpe ramon', 'Yeroham']
# Group 5: ['Elat']
# Group 6: ["'afula", "'ein mahel", "'ilut", "Bet she'an", 'Bir el-maksur', "Bu'eine-nujeidat", 'Dabburiyya', 'Iksal', 'Kafar kama', 'Kafar kanna', 'Kefar tavor', 'Mashhed', "Migdal ha'emeq", 'Muqeible', "Na'ura", 'Naz?erat', "Naz?erat 'illit", 'Nein', 'Reine', 'Rumat heib', 'Sulam', 'Tiberias', 'Timrat', "Tur'an", 'Uzeir', "Yavne'el"]
# Group 7: ["'ein qiniyye", "'ofra", 'Abu ghosh', 'Allon shevut', "Ari'el", 'Bet el', 'Bet shemesh', 'Betar illit', 'Efrata', 'Eli', "Giv'at ze'ev", 'Har adar', 'Kefar adummim', "Kokhav ya'aqov", "Ma'ale adummim", 'Mevasserat ziyyon', "Modi'in-makkabim-re'ut", 'Qiryat arba', "Qiryat ye'arim", 'Shilo', 'Talmon', 'Yerushalayim', 'Z?ur hadassa']
# Group 8: ["'ar'ara", 'Baqa-jatt', 'Bet yizhaq', 'Elyakhin', 'Even yehuda', 'Fureidis', 'H?adera', 'Jisr az-zarqa', "Kafar qara'", 'Kefar yona', 'Netanya', 'Nordiyya', "Or 'aqiva", 'Pardes h?anna-karkur', 'Pardesiyya', 'Qalansawe', 'Qedummim', 'Qesarya', 'Tayibe', 'Tel mond', 'Tire', 'Umm al-fahm', 'Z?oran-qadima', "Zikhron ya'aqov"]
# Group 9: ['Ashdod', 'Ashqelon', 'Bene ayish', 'Gan yavne', 'Netivot', 'Newe deqalim', 'Ofaqim', 'Qiryat gat', "Qiryat mal'akhi", 'Sederot']
# Group 10: ["'arrabe", "'eilabun", 'Beit jann', 'Deir hanna', 'Fassuta', 'Haz?or hagelilit', 'Hurfeish', 'Jish', 'Karmiel', 'Kefar weradim', 'Kisra-sumei', "Ma'alot-tarshih?a", "Mi'elya", 'Mugar', 'Nahef', "Peqi'in", 'Qiryat shemona', 'Rame', 'Rosh pinna', 'Sajur', 'Sakhnin', 'Sallama', 'Shagor', 'Tuba-zangariyye', 'Z?efat']

# %%
kmeans_print_groups(n_clusters=40)
# Out:
# Group 1: ['Bet yizhaq', 'Even yehuda', 'Kefar yona', 'Netanya', 'Nordiyya', 'Pardesiyya', 'Qalansawe', 'Tayibe', 'Tel mond', 'Tire', 'Z?oran-qadima']
# Group 2: ["Binyamina-giv'at ada"]
# Group 3: ['Beit jann', 'Deir hanna', 'Mugar', 'Rame', 'Sallama']
# Group 4: ['Dimona', 'Yeroham']
# Group 5: ["'ein qiniyye", "'ofra", 'Bet el', "Giv'at ze'ev", "Kokhav ya'aqov", 'Talmon']
# Group 6: ['Ashdod', 'Bene ayish', 'Gan yavne', 'Gedera', 'Qiryat gat', "Qiryat mal'akhi"]
# Group 7: ['Elat']
# Group 8: ["I'billin", 'Kabul', 'Kafar manda', 'Sakhnin', 'Segev-shalom', "Sha'ab", 'Shagor', "Shefar'am", 'Tamra']
# Group 9: ['Azur', 'Bat yam', 'Bene beraq', 'Bet dagan', 'Ganne tiqwa', "Giv'at shemuel", "Giv'atayim", 'H?olon', 'Kefar habad', 'Nehalim', 'Or yehuda', 'Petah? tiqwa', 'Qiryat ono', "Ramat ef'al", 'Ramat gan', 'Savyon', 'Tel aviv-yafo', 'Yehud-newe efrayim']
# Group 10: ['Netivot', 'Ofaqim']
# Group 11: ['Merkaz shappira']
# Group 12: ["'atlit", 'Fureidis', 'Jisr az-zarqa', "Or 'aqiva", "Zikhron ya'aqov"]
# Group 13: ["'afula", 'Muqeible', "Na'ura", 'Nein', 'Sulam']
# Group 14: ['Qiryat arba']
# Group 15: ['Alfe menashe', 'Elqana', 'Jaljulye', 'Kafar qasem', 'Oranit', 'Rosh haayin', "Sha'are tiqwa"]
# Group 16: ['Haifa', 'Nesher', 'Qiryat atta', 'Qiryat bialik', 'Qiryat motzkin', 'Qiryat yam', 'Tirat karmel']
# Group 17: ['Fassuta', 'Hurfeish', 'Karmiel', 'Kefar weradim', 'Kisra-sumei', "Ma'alot-tarshih?a", "Mi'elya", 'Nahef', "Peqi'in", 'Sajur']
# Group 18: ["'ein mahel", "'ilut", 'Bir el-maksur', 'Iksal', 'Mashhed', "Migdal ha'emeq", 'Naz?erat', "Naz?erat 'illit", 'Reine', 'Timrat']
# Group 19: ["'akko", "'ir hahamisha", 'Judeide-maker', 'Kafar yasif', "Mazra'a", 'Nahariyya', 'Sheikh dannun', 'Shelomi']
# Group 20: ['Allon shevut', 'Bet shemesh', 'Betar illit', 'Efrata', 'Z?ur hadassa']
# Group 21: ['Qiryat shemona']
# Group 22: ['Kefar adummim', "Ma'ale adummim"]
# Group 23: ['Mizpe ramon']
# Group 24: ['Newe deqalim']
# Group 25: ['Elyakhin', 'H?adera', 'Pardes h?anna-karkur', 'Qesarya']
# Group 26: ['Haz?or hagelilit', 'Jish', 'Rosh pinna', 'Tuba-zangariyye', 'Z?efat']
# Group 27: ["'omer", "Be'er sheva"]
# Group 28: ["Be'er ya'aqov", 'Mazkeret batya', 'Nes z?iyyona', "Qiryat 'eqron", 'Ramla', 'Reh?ovot', 'Rishon lez?iyyon', 'Yavne']
# Group 29: ['Ashqelon', 'Sederot']
# Group 30: ["'immanu'el", "Ari'el", 'Qarne shomeron', 'Qedummim']
# Group 31: ["'arad", 'Kuseife']
# Group 32: ["Basmat tab'un", "Daliyat al karmel-'isifya", 'Ibtin', "Qiryat tiv'on", 'Ramat yishay', 'Rekhasim', "Yoqne'am illit"]
# Group 33: ['Herzeliyya', 'Hod hasharon', 'Kefar sava', 'Kefar shemaryahu', "Ra'anana", 'Ramat hasharon']
# Group 34: ["'ar'ara", 'Baqa-jatt', "Kafar qara'", 'Umm al-fahm']
# Group 35: ['Eli', 'Shilo']
# Group 36: ['Dabburiyya', 'Kafar kama', 'Kefar tavor', 'Tiberias', "Yavne'el"]
# Group 37: ['Abu ghosh', 'Har adar', 'Mevasserat ziyyon', "Qiryat ye'arim", 'Yerushalayim']
# Group 38: ["'arrabe", "'eilabun", "Bu'eine-nujeidat", 'Kafar kanna', 'Rumat heib', "Tur'an", 'Uzeir']
# Group 39: ["Bet she'an"]
# Group 40: ['Bet arye', 'Lod', "Modi'in-makkabim-re'ut", 'Shoham']

# %%
# TODO: add elevation consideration?
